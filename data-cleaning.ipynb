# %%
import pandas as pd

songs = pd.read_csv('data/spotify_data.csv', index_col=[0])
# songs.drop_duplicates(inplace=True, keep='first')
songs.dropna(inplace=True)
explicit = songs['explicit'].astype(int).to_numpy()
songs['explicit'] = explicit
unique_trackids = songs.drop_duplicates(subset='track_id', keep='first')
unique_trackids = unique_trackids.set_index(['track_id'])
same_trackid = songs[songs.duplicated(subset=['track_id'], keep=False)].sort_values(by='track_id')
same_trackid.head()
# Out:
#                       track_id            artists                album_name  \
# 15028   001APMDOl3qtx1526T11n1  Pink Sweat$;Kirby                   New RnB
# 103211  001APMDOl3qtx1526T11n1  Pink Sweat$;Kirby                   New RnB
# 85578   001YQlnDSduXd5LgBd66gT        Soda Stereo  Soda Stereo (Remastered)
# 100420  001YQlnDSduXd5LgBd66gT        Soda Stereo  Soda Stereo (Remastered)
# 91801   003vvx7Niy0yvhvHt4a68B        The Killers                  Hot Fuss
#
#                                       track_name  popularity  duration_ms  \
# 15028                                     Better           0       176320
# 103211                                    Better           0       176320
# 85578   El Tiempo Es Dinero - Remasterizado 2007          38       177266
# 100420  El Tiempo Es Dinero - Remasterizado 2007          38       177266
# 91801                             Mr. Brightside          86       222973
#
#         explicit  danceability  energy  key  loudness  mode  speechiness  \
# 15028          0         0.613   0.471    1    -6.644     0       0.1070
# 103211         0         0.613   0.471    1    -6.644     0       0.1070
# 85578          0         0.554   0.921    2    -4.589     1       0.0758
# 100420         0         0.554   0.921    2    -4.589     1       0.0758
# 91801          0         0.352   0.911    1    -5.230     1       0.0747
#
#         acousticness  instrumentalness  liveness  valence    tempo  \
# 15028        0.31600          0.000001    0.1170    0.406  143.064
# 103211       0.31600          0.000001    0.1170    0.406  143.064
# 85578        0.01940          0.088100    0.3290    0.700  183.571
# 100420       0.01940          0.088100    0.3290    0.700  183.571
# 91801        0.00121          0.000000    0.0995    0.236  148.033
#
#         time_signature track_genre
# 15028                4       chill
# 103211               4        soul
# 85578                1   punk-rock
# 100420               1         ska
# 91801                4        rock

# %%
by_track_id = same_trackid.groupby(['track_id'], as_index=False).agg({'track_genre': ' '.join})
print(by_track_id)
# Out:
#                      track_id                    track_genre
# 0      001APMDOl3qtx1526T11n1                     chill soul
# 1      001YQlnDSduXd5LgBd66gT                  punk-rock ska
# 2      003vvx7Niy0yvhvHt4a68B      rock alternative alt-rock
# 3      004h8smbIoAkUNDJvVKwkG                        emo sad
# 4      006rHBBNLJMpQs8fRC2GDe         sertanejo pagode forro
# ...                       ...                            ...
# 16636  7ztSVy67w9rXpKg5L2zN5l                   indie indian
# 16637  7zubR9uYAWjb5KPZTMm85e  latino latin reggaeton reggae
# 16638  7zumacGldlmxpoP8bpaeLe            power-pop synth-pop
# 16639  7zv2vmZq8OjS54BxFzI2wM          metalcore death-metal
# 16640  7zwn1eykZtZ5LODrf7c0tS      alt-rock alternative rock
#
# [16641 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler
string_columns = ['track_name', 'track_id', 'album_name', 'artists']
numerical_data = songs.drop(columns=string_columns)
by_genre = numerical_data.groupby('track_genre').mean()
scaler = StandardScaler()
scaler.fit(numerical_data.values)
by_genre[by_genre.columns] = scaler.transform(by_genre.values)

# %%
import numpy as np

id_to_selected_genre = {}
for track_id, genres in by_track_id.to_numpy():
    record_values = unique_trackids.loc[track_id]
    numerical_values = record_values.drop(index=['artists', 'album_name', 'track_name', 'track_genre'])
    scaled = scaler.transform(numerical_values.to_numpy().reshape(1, -1))
    song_vector = scaled.flatten()
    distances = []
    # Compute distance from each genre to the current song
    for genre in genres.split(" "):
        genre_vector = by_genre.loc[genre]
        distance = np.linalg.norm(song_vector - genre_vector, ord=1)
        distances.append((genre, distance))
    # Select genre with the smallest distance
    selected_genre = min(distances, key=lambda x: x[1])[0]
    id_to_selected_genre[track_id] = selected_genre

# %%
# Replace genre of tracks with multiple genres by the genre with the smallest distance
for track_id, genre in id_to_selected_genre.items():
    unique_trackids.at[track_id, 'track_genre'] = genre

# %%
unique_trackids[unique_trackids['track_genre'] == 'disney']
# Out:
#                      track_id  \
# 14041  5d22scOOfbrK7GHy3ZTT3s
# 24549  1ymvyDsiAUbzEhmSkfCSYh
# 24552  3dfpZwSuosIuFqksY0F6gT
# 24555  5fBcRH4CnYTaFMQtM0JtSl
# 24556  0juMU08O9byWiRBtKM1j5E
# ...                       ...
# 25542  7buYPUijQW1xk8JsB6BoVk
# 25543  4aSt3lGu5Rd9BTUjkIK9MR
# 25544  34rDgdMzrvGPC282kF4Eu4
# 25545  0son51AkdDBGl5v1Bx12Cu
# 25546  48bLCSUwsZ1GKrahExEyk4
#
#                                                  artists  \
# 14041                     Jim Cummings;Terence Blanchard
# 24549  Billy Eichner;Seth Rogen;JD McCrary;Childish G...
# 24552                       Cast - Sofia the First;Sofia
# 24555                           Alanna Ubach;Antonio Sol
# 24556                             Lindiwe Mkhize;Lebo M.
# ...                                                  ...
# 25542                                        André Leono
# 25543                                        Alan Menken
# 25544                                       George Bruns
# 25545                                       Kristen Bell
# 25546                                 Alan Menken;Disney
#
#                                               album_name  \
# 14041  The Princess and the Frog (Original Motion Pic...
# 24549  The Lion King (Original Motion Picture Soundtr...
# 24552                                    Sofia the First
# 24555          Coco (Original Motion Picture Soundtrack)
# 24556  The Lion King (Original Motion Picture Soundtr...
# ...                                                  ...
# 25542                                 Coração Sem Abrigo
# 25543  Pocahontas, Une Légende Indienne (Bande Origin...
# 25544                                     101 Dalmatians
# 25545  Frost 2 (Svenskt Original Soundtrack/Deluxe Ed...
# 25546                                La Belle et La Bête
#
#                                               track_name  popularity  \
# 14041                                Ma Belle Evangeline          65
# 24549                                      Hakuna Matata          58
# 24552  Sofia the First Main Title Theme - From "Sofia...          55
# 24555                                         La Llorona          56
# 24556                    Circle of Life/Nants' Ingonyama          56
# ...                                                  ...         ...
# 25542                           Olha o Que o Amor Me Faz          18
# 25543  I'll Never See Him Again - From "Pocahontas"/S...          19
# 25544  All Dog Alert - From "101 Dalmatians"/Score Ve...          18
# 25545                                     Home - Outtake          18
# 25546  Transformation - From "Beauty and the Beast"/S...          19
#
#        duration_ms  explicit  danceability  energy  key  loudness  mode  \
# 14041       115693         0         0.378  0.3520    3    -8.745     1
# 24549       251520         0         0.530  0.5840    0   -11.891     1
# 24552        52866         0         0.655  0.7890    4    -3.995     1
# 24555       165533         0         0.460  0.5740    4    -7.414     0
# 24556       241800         0         0.297  0.5180   10    -8.152     1
# ...            ...       ...           ...     ...  ...       ...   ...
# 25542       213680         0         0.480  0.3010    3   -10.960     1
# 25543       114240         0         0.156  0.0788    7   -18.245     1
# 25544        57906         0         0.629  0.6190    0   -17.621     1
# 25545       176865         0         0.708  0.4240    2    -7.048     1
# 25546       347906         0         0.210  0.1960    9   -16.557     1
#
#        speechiness  acousticness  instrumentalness  liveness  valence  \
# 14041       0.0354         0.812          0.000005    0.1060   0.3060
# 24549       0.2180         0.274          0.000000    0.1580   0.5750
# 24552       0.0489         0.423          0.000000    0.1300   0.6600
# 24555       0.1120         0.318          0.000000    0.1000   0.3700
# 24556       0.0378         0.412          0.000011    0.2980   0.4960
# ...            ...           ...               ...       ...      ...
# 25542       0.0357         0.339          0.000000    0.1550   0.1650
# 25543       0.0361         0.969          0.951000    0.3670   0.0398
# 25544       0.0606         0.835          0.032700    0.1790   0.4000
# 25545       0.0353         0.724          0.000000    0.0722   0.6370
# 25546       0.0381         0.854          0.619000    0.0721   0.0687
#
#          tempo  time_signature track_genre
# 14041  139.491               5      disney
# 24549   81.854               4      disney
# 24552   92.968               4      disney
# 24555   67.697               4      disney
# 24556   81.425               4      disney
# ...        ...             ...         ...
# 25542  127.573               4      disney
# 25543   87.453               3      disney
# 25544  118.186               1      disney
# 25545  101.703               4      disney
# 25546  114.714               4      disney
#
# [944 rows x 20 columns]

# %%
# Save to csv
unique_trackids.reset_index(inplace=True)
unique_trackids.to_csv('data/spotify_clean.csv', header=True)
